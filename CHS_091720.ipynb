# %% [markdown]
# #PYSAL Workshop

# %%
import rasterio
from rasterio.merge import merge
from rasterio.plot import show
from rasterio import plot
import glob
import os
# %matplotlib inline

# %%
# File and folder paths
dirpath = (r"D:\SwimmingPoolProject\data\NAIP_SI")
out_fp = os.path.join(dirpath, "SI_Mosaic.tif")

# %%
import os
import matplotlib.pyplot as plt
import numpy as np
import geopandas as gpd

# %%
#DEM

# %%
files_to_mosaic_DEM = [r'D:\SwimmingPoolProject\data\tiff\DEM\be_NYC_001.tif',
                   r'D:\SwimmingPoolProject\data\tiff\DEM\be_NYC_002.tif',
                   r'D:\SwimmingPoolProject\data\tiff\DEM\be_NYC_004.tif',
                   r'D:\SwimmingPoolProject\data\tiff\DEM\be_NYC_005.tif',
                   r'D:\SwimmingPoolProject\data\tiff\DEM\be_NYC_006.tif',
                   r'D:\SwimmingPoolProject\data\tiff\DEM\be_NYC_007.tif',
                   r'D:\SwimmingPoolProject\data\tiff\DEM\be_NYC_008.tif',
                   r'D:\SwimmingPoolProject\data\tiff\DEM\be_NYC_009.tif',
                   r'D:\SwimmingPoolProject\data\tiff\DEM\be_NYC_012.tif',
                   r'D:\SwimmingPoolProject\data\tiff\DEM\be_NYC_013.tif',
                   r'D:\SwimmingPoolProject\data\tiff\DEM\be_NYC_014.tif'
]

# %%
files_string_DEM = " ".join(files_to_mosaic_DEM)
print(files_string_DEM)
# Out:
# D:\SwimmingPoolProject\data\tiff\DEM\be_NYC_001.tif D:\SwimmingPoolProject\data\tiff\DEM\be_NYC_002.tif D:\SwimmingPoolProject\data\tiff\DEM\be_NYC_004.tif D:\SwimmingPoolProject\data\tiff\DEM\be_NYC_005.tif D:\SwimmingPoolProject\data\tiff\DEM\be_NYC_006.tif D:\SwimmingPoolProject\data\tiff\DEM\be_NYC_007.tif D:\SwimmingPoolProject\data\tiff\DEM\be_NYC_008.tif D:\SwimmingPoolProject\data\tiff\DEM\be_NYC_009.tif D:\SwimmingPoolProject\data\tiff\DEM\be_NYC_012.tif D:\SwimmingPoolProject\data\tiff\DEM\be_NYC_013.tif D:\SwimmingPoolProject\data\tiff\DEM\be_NYC_014.tif

# %%
# List for the source files
src_files_to_mosaic_DEM = []

# %%
for fp in files_to_mosaic_DEM:
    src = rasterio.open(fp)
    src_files_to_mosaic_DEM.append(src)

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# Create 4 plots next to each other
fig, (ax1, ax2, ax3, ax4) = plt.subplots(ncols=4, nrows=1, figsize=(12, 4))

# Plot first four files
show(src_files_to_mosaic_DEM[0], ax=ax1)
show(src_files_to_mosaic_DEM[1], ax=ax2)
show(src_files_to_mosaic_DEM[2], ax=ax3)
show(src_files_to_mosaic_DEM[3], ax=ax4)

# Do not show y-ticks values in last three axis
for ax in [ax2, ax3, ax4]:
    ax.yaxis.set_visible(False)

# %%
# Merge function returns a single mosaic array and the transformation info
mosaic_DEM, out_trans = merge(src_files_to_mosaic_DEM)

# Plot the result
show(mosaic_DEM, cmap='terrain')
# Out:
# <AxesSubplot:>

# %%
### DSM

# %%
files_to_mosaic_DSM = [r'D:\SwimmingPoolProject\data\tiff\DSM\hh_NYC_001.tif',
                       r'D:\SwimmingPoolProject\data\tiff\DSM\hh_NYC_002.tif',
                       r'D:\SwimmingPoolProject\data\tiff\DSM\hh_NYC_004.tif',
                       r'D:\SwimmingPoolProject\data\tiff\DSM\hh_NYC_005.tif',
                       r'D:\SwimmingPoolProject\data\tiff\DSM\hh_NYC_006.tif',
                       r'D:\SwimmingPoolProject\data\tiff\DSM\hh_NYC_012.tif',
                       r'D:\SwimmingPoolProject\data\tiff\DSM\hh_NYC_013.tif'
                    ]

# %%
files_string_DSM = " ".join(files_to_mosaic_DSM)
print(files_string_DSM)
# Out:
# D:\SwimmingPoolProject\data\tiff\DSM\hh_NYC_001.tif D:\SwimmingPoolProject\data\tiff\DSM\hh_NYC_002.tif D:\SwimmingPoolProject\data\tiff\DSM\hh_NYC_004.tif D:\SwimmingPoolProject\data\tiff\DSM\hh_NYC_005.tif D:\SwimmingPoolProject\data\tiff\DSM\hh_NYC_006.tif D:\SwimmingPoolProject\data\tiff\DSM\hh_NYC_012.tif D:\SwimmingPoolProject\data\tiff\DSM\hh_NYC_013.tif

# %%
# List for the source files
src_files_to_mosaic_DSM = []

# %%
for fp in files_to_mosaic_DSM:
    src = rasterio.open(fp)
    src_files_to_mosaic_DSM.append(src)

# %%
src_files_to_mosaic_DSM
# Out:
# [<open DatasetReader name='D:/SwimmingPoolProject/data/tiff/DSM/hh_NYC_001.tif' mode='r'>,
#  <open DatasetReader name='D:/SwimmingPoolProject/data/tiff/DSM/hh_NYC_002.tif' mode='r'>,
#  <open DatasetReader name='D:/SwimmingPoolProject/data/tiff/DSM/hh_NYC_004.tif' mode='r'>,
#  <open DatasetReader name='D:/SwimmingPoolProject/data/tiff/DSM/hh_NYC_005.tif' mode='r'>,
#  <open DatasetReader name='D:/SwimmingPoolProject/data/tiff/DSM/hh_NYC_006.tif' mode='r'>,
#  <open DatasetReader name='D:/SwimmingPoolProject/data/tiff/DSM/hh_NYC_012.tif' mode='r'>,
#  <open DatasetReader name='D:/SwimmingPoolProject/data/tiff/DSM/hh_NYC_013.tif' mode='r'>]

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# Create 4 plots next to each other
fig, (ax1, ax2, ax3, ax4) = plt.subplots(ncols=4, nrows=1, figsize=(12, 4))

# Plot first four files
show(src_files_to_mosaic_DSM[0], ax=ax1)
show(src_files_to_mosaic_DSM[1], ax=ax2)
show(src_files_to_mosaic_DSM[2], ax=ax3)
show(src_files_to_mosaic_DSM[3], ax=ax4)

# Do not show y-ticks values in last three axis
for ax in [ax2, ax3, ax4]:
    ax.yaxis.set_visible(False)

# %%
# Merge function returns a single mosaic array and the transformation info
mosaic_DSM, out_trans = merge(src_files_to_mosaic_DEM)

# Plot the result
show(mosaic_DSM, cmap='terrain')
# Out:
# <AxesSubplot:>

# %%
#CHS
#https://www.earthdatascience.org/courses/earth-analytics/lidar-raster-data-r/lidar-chm-dem-dsm/

# %%
# Convert to floats
DSM = mosaic_DSM.astype('f4')
r"D:\SwimmingPoolProject\data\NAIP_SI"

# %%
with rio.open(out_path, 'w', **chm_meta) as outf:
    outf.write(lidar_chm_im_fi, 1)

# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-24-ab1d4a5d0199> in <module>
# ----> 1 writeRaster(DSM,"D:/SwimmingPoolProject/data/NAIP_SI/SI_DSM.tiff",
#       2             format = "GTiff",  # output format = GeoTIFF
#       3             overwrite = TRUE) # CAUTION: if this is true, it will overwrite an existing file
#
# NameError: name 'writeRaster' is not defined

# %%
DEM = mosaic_DEM.astype('f4')
# Out:
# ---------------------------------------------------------------------------
# MemoryError                               Traceback (most recent call last)
# <ipython-input-21-47682c3c1ed9> in <module>
# ----> 1 DEM = mosaic_DEM.astype('f4')
#
# MemoryError: Unable to allocate 26.2 GiB for an array with shape (1, 56605, 124168) and data type float32

# %%
np.seterr(divide='ignore', invalid='ignore')

# %%
# Calculate NDVI using numpy arrays
CHS = DSM - DEM

# %%
# %matplotlib inline
# Plot the NDVI
plt.imshow(CHS, cmap='terrain_r')
# Add colorbar to show the index
plt.colorbar()
